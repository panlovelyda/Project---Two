# %%
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy import inspect

# %%
interest_file  = "Resources/interest.csv"
interest_df = pd.read_csv(interest_file,encoding='cp1252')
interest_df.head()
# Out:
#    F1.1 INTEREST RATES AND YIELDS – MONEY MARKET  \
# 0                                          Title
# 1                                    Description
# 2                                      Frequency
# 3                                           Type
# 4                                          Units
# ..                                           ...
# 95                                      Jul-1976
# 96                                      Aug-1976
# 97                                      Sep-1976
# 98                                      Oct-1976
# 99                                      Nov-1976
#
#                            Unnamed: 1  \
# 0                    Cash Rate Target
# 1   Cash Rate Target; monthly average
# 2                             Monthly
# 3                            Original
# 4                            Per cent
# ..                                ...
# 95                                NaN
# 96                                NaN
# ...
