# %%
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy import inspect
from login import uname, pw

# %%
interest_file  = "Resources/interest.csv"
interest_df = pd.read_csv(interest_file,encoding='cp1252',skiprows=[0,2,3,4,5,6,7,8,9,10])
interest_df.head()
# Out:
#       Title  Cash Rate Target  Interbank Overnight Cash Rate  \
# 0  Jun-1969               NaN                            NaN
# 1  Jul-1969               NaN                            NaN
# 2  Aug-1969               NaN                            NaN
# 3  Sep-1969               NaN                            NaN
# 4  Oct-1969               NaN                            NaN
#
#    Highest Interbank Overnight Cash Rate  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    Lowest Interbank Overnight Cash Rate  Volume of Cash Market Transactions  \
# 0                                   NaN                                 NaN
# 1                                   NaN                                 NaN
# 2                                   NaN                                 NaN
# 3                                   NaN                                 NaN
# 4                                   NaN                                 NaN
#
#    Number of Cash Market Transactions  1-month BABs/NCDs  3-month BABs/NCDs  \
# 0                                 NaN                NaN                5.9
# 1                                 NaN                NaN                5.8
# 2                                 NaN                NaN                6.1
# 3                                 NaN                NaN                5.8
# 4                                 NaN                NaN                5.6
#
#    6-month BABs/NCDs  ...  3-month OIS  6-month OIS  1-month Treasury Note  \
# 0                NaN  ...          NaN          NaN                    NaN
# 1                NaN  ...          NaN          NaN                    NaN
# 2                NaN  ...          NaN          NaN                    NaN
# 3                NaN  ...          NaN          NaN                    NaN
# 4                NaN  ...          NaN          NaN                    NaN
#
#    3- month Treasury Note  6- month Treasury Note  Unnamed: 16  Unnamed: 17  \
# 0                     NaN                     NaN          NaN          NaN
# 1                     NaN                     NaN          NaN          NaN
# 2                     NaN                     NaN          NaN          NaN
# 3                     NaN                     NaN          NaN          NaN
# 4                     NaN                     NaN          NaN          NaN
#
#    Unnamed: 18  Unnamed: 19  Unnamed: 20
# 0          NaN          NaN          NaN
# 1          NaN          NaN          NaN
# 2          NaN          NaN          NaN
# 3          NaN          NaN          NaN
# 4          NaN          NaN          NaN
#
# [5 rows x 21 columns]

# %%
interest_new_data_df = interest_df[['Title', 'Cash Rate Target', 'Interbank Overnight Cash Rate','1-month BABs/NCDs','3-month BABs/NCDs','6-month BABs/NCDs']].copy()
interest_new_data_df = interest_new_data_df.rename(columns={'Title':'Date'})
interest_new_data_df.head()
# Out:
#        Date  Cash Rate Target  Interbank Overnight Cash Rate  \
# 0  Jun-1969               NaN                            NaN
# 1  Jul-1969               NaN                            NaN
# 2  Aug-1969               NaN                            NaN
# 3  Sep-1969               NaN                            NaN
# 4  Oct-1969               NaN                            NaN
#
#    1-month BABs/NCDs  3-month BABs/NCDs  6-month BABs/NCDs
# 0                NaN                5.9                NaN
# 1                NaN                5.8                NaN
# 2                NaN                6.1                NaN
# 3                NaN                5.8                NaN
# 4                NaN                5.6                NaN

# %%
interest_new_data_df['Date']= pd.to_datetime(interest_new_data_df['Date'])

# %%
interest_new_data_df['quarter']= pd.PeriodIndex(interest_new_data_df.Date, freq ='Q')
interest_new_data_df
# Out:
#           Date  Cash Rate Target  Interbank Overnight Cash Rate  \
# 0   1969-06-01               NaN                            NaN
# 1   1969-07-01               NaN                            NaN
# 2   1969-08-01               NaN                            NaN
# 3   1969-09-01               NaN                            NaN
# 4   1969-10-01               NaN                            NaN
# ..         ...               ...                            ...
# 701        NaT               NaN                            NaN
# 702        NaT               NaN                            NaN
# 703        NaT               NaN                            NaN
# 704        NaT               NaN                            NaN
# 705        NaT               NaN                            NaN
#
#      1-month BABs/NCDs  3-month BABs/NCDs  6-month BABs/NCDs quarter
# 0                  NaN                5.9                NaN  1969Q2
# 1                  NaN                5.8                NaN  1969Q3
# 2                  NaN                6.1                NaN  1969Q3
# 3                  NaN                5.8                NaN  1969Q3
# 4                  NaN                5.6                NaN  1969Q4
# ..                 ...                ...                ...     ...
# 701                NaN                NaN                NaN     NaT
# 702                NaN                NaN                NaN     NaT
# 703                NaN                NaN                NaN     NaT
# 704                NaN                NaN                NaN     NaT
# 705                NaN                NaN                NaN     NaT
#
# [706 rows x 7 columns]

# %%
interest_new_data_df.dropna(inplace=True)
interest_new_data_df
# Out:
#           Date  Cash Rate Target  Interbank Overnight Cash Rate  \
# 277 1992-07-01              5.91                           5.93
# 278 1992-08-01              5.75                           5.86
# 279 1992-09-01              5.75                           5.74
# 280 1992-10-01              5.75                           5.74
# 281 1992-11-01              5.75                           5.77
# ..         ...               ...                            ...
# 635 2022-05-01              0.33                           0.29
# 636 2022-06-01              0.73                           0.69
# 637 2022-07-01              1.28                           1.24
# 638 2022-08-01              1.81                           1.77
# 639 2022-09-01              2.25                           2.21
#
#      1-month BABs/NCDs  3-month BABs/NCDs  6-month BABs/NCDs quarter
# 277               5.84               5.64               5.50  1992Q3
# 278               5.88               5.73               5.66  1992Q3
# 279               5.91               5.94               5.99  1992Q3
# 280               5.86               5.86               5.88  1992Q4
# 281               5.88               5.88               5.92  1992Q4
# ..                 ...                ...                ...     ...
# 635               0.39               1.00               1.79  2022Q2
# 636               0.92               1.60               2.48  2022Q2
# 637               1.48               2.07               2.87  2022Q3
# 638               1.89               2.31               2.92  2022Q3
# 639               2.41               2.76               3.26  2022Q3
#
# [363 rows x 7 columns]

# %%
interest_new_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 363 entries, 277 to 639
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Date                           363 non-null    datetime64[ns]
#  1   Cash Rate Target               363 non-null    float64
#  2   Interbank Overnight Cash Rate  363 non-null    float64
#  3   1-month BABs/NCDs              363 non-null    float64
#  4   3-month BABs/NCDs              363 non-null    float64
#  5   6-month BABs/NCDs              363 non-null    float64
#  6   quarter                        363 non-null    period[Q-DEC]
# dtypes: datetime64[ns](1), float64(5), period[Q-DEC](1)
# memory usage: 22.7 KB

# %%
protocol = 'postgresql'
host = 'localhost'
port = 5432
database_name = 'project2_db'
rds_connection_string = f'{protocol}://{uname}:{pw}@{host}:{port}/{database_name}'
print(rds_connection_string)
engine = create_engine(rds_connection_string)
insp = inspect(engine)
# Out:
# postgresql://andoh123:daproject22@localhost:5432/project2_db
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\tfred\OneDrive\Documents\Monash Uni Bootcamp\Project---Two\Project---Two\interest.ipynb Cell 8 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/c%3A/Users/tfred/OneDrive/Documents/Monash%20Uni%20Bootcamp/Project---Two/Project---Two/interest.ipynb#W3sZmlsZQ%3D%3D?line=4'>5</a> rds_connection_string = f'{protocol}://{uname}:{pw}@{host}:{port}/{database_name}'
#       <a href='vscode-notebook-cell:/c%3A/Users/tfred/OneDrive/Documents/Monash%20Uni%20Bootcamp/Project---Two/Project---Two/interest.ipynb#W3sZmlsZQ%3D%3D?line=5'>6</a> print(rds_connection_string)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/tfred/OneDrive/Documents/Monash%20Uni%20Bootcamp/Project---Two/Project---Two/interest.ipynb#W3sZmlsZQ%3D%3D?line=6'>7</a> engine = create_engine(rds_connection_string)
#       <a href='vscode-notebook-cell:/c%3A/Users/tfred/OneDrive/Documents/Monash%20Uni%20Bootcamp/Project---Two/Project---Two/interest.ipynb#W3sZmlsZQ%3D%3D?line=7'>8</a> insp = inspect(engine)
#      <a href='vscode-notebook-cell:/c%3A/Users/tfred/OneDrive/Documents/Monash%20Uni%20Bootcamp/Project---Two/Project---Two/interest.ipynb#W3sZmlsZQ%3D%3D?line=9'>10</a> print(rds_connection_string)
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File c:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\deprecations.py:309, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     302     if m in kwargs:
#     303         _warn_with_version(
#     304             messages[m],
#     305             versions[m],
#     306             version_warnings[m],
#     307             stacklevel=3,
#     308         )
# --> 309 return fn(*args, **kwargs)
#
# File c:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\create.py:560, in create_engine(url, **kwargs)
#     558         if k in kwargs:
#     559             dbapi_args[k] = pop_kwarg(k)
# --> 560     dbapi = dialect_cls.dbapi(**dbapi_args)
#     562 dialect_args["dbapi"] = dbapi
#     564 dialect_args.setdefault("compiler_linting", compiler.NO_LINTING)
#
# File c:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py:782, in PGDialect_psycopg2.dbapi(cls)
#     780 @classmethod
#     781 def dbapi(cls):
# --> 782     import psycopg2
#     784     return psycopg2
#
# ModuleNotFoundError: No module named 'psycopg2'

# %%
interest_new_data_df.to_sql(name='interest', con=engine, if_exists='replace', index=True)
